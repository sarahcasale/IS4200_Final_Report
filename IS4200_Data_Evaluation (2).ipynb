# %%
# load dataset
# %pip install ir_datasets
import ir_datasets
dataset = ir_datasets.load("cord19/trec-covid")
print(f"queries: {dataset.queries_count()}, docs: {dataset.docs_count()}, qrels: {dataset.qrels_count()}")
# Out:
# Requirement already satisfied: ir_datasets in /usr/local/lib/python3.10/dist-packages (0.5.5)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (4.11.2)
# Requirement already satisfied: inscriptis>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (2.3.2)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (4.9.3)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (1.23.5)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (6.0.1)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (4.66.1)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (2.6)
# Requirement already satisfied: lz4>=3.1.10 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (4.3.2)
# Requirement already satisfied: warc3-wet>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (0.2.3)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (0.1.6)
# Requirement already satisfied: ijson>=3.1.3 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (3.2.3)
# Requirement already satisfied: pyautocorpus>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (0.1.12)
# Requirement already satisfied: unlzw3>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (0.2.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->ir_datasets) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->ir_datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->ir_datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->ir_datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->ir_datasets) (2023.11.17)
# Requirement already satisfied: cbor>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from trec-car-tools>=2.5.4->ir_datasets) (1.0.0)
# queries: 50, docs: 192509, qrels: 69318

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# convert the collection in a dataframe
queries = pd.DataFrame(dataset.queries_iter())
docs = pd.DataFrame(dataset.docs_iter())
qrels = pd.DataFrame(dataset.qrels_iter())

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string

# Preprocess function
def preprocess(text):
    # Convert to string if not already
    text = str(text)
    # Lowercase
    text = text.lower()
    # Tokenize
    tokens = word_tokenize(text)
    # Remove punctuation and stopwords
    tokens = [t for t in tokens if t not in string.punctuation]
    tokens = [t for t in tokens if t not in stopwords.words('english')]
    return ' '.join(tokens)

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')

queries_data = queries
docs_data = docs[:1000]

display(queries_data.sample(5))
display(docs_data.sample(5))


# Apply preprocessing to text columns
queries['title'] = queries_data['title'].apply(preprocess)
queries['description'] = queries_data['description'].apply(preprocess)
docs['title'] = docs_data['title'].apply(preprocess)
docs['abstract'] = docs_data['abstract'].apply(preprocess)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#    query_id                             title  \
# 25       26        coronavirus early symptoms
# 45       46         dexamethasone coronavirus
# 48       49  post-infection COVID-19 immunity
# 37       38       COVID inflammatory response
# 10       11    coronavirus hospital rationing
#
#                                           description  \
# 25         what are the initial symptoms of Covid-19?
# 45  what evidence is there for dexamethasone as a ...
# 48  do individuals who recover from COVID-19 show ...
# 37  What is the mechanism of inflammatory response...
# 10  what are the guidelines for triaging patients ...
#
#                                             narrative
# 25  Studies of patients and the first clinical man...
# 45  Looking for studies on the impact of dexametha...
# 48  There is concern about re-infection for COVID-...
# 37  Looking for a range of studies which describes...
# 10  Seeking information on any guidelines for prio...
#        doc_id                                              title  \
# 515  4prvgmvt             Nursing heroism in the 21(st )Century'
# 725  bbjmcdo5  True versus False Parasite Interactions: A Rob...
# 76   cxzlmfst  Automated identification of multiple micro-org...
# 522  0gt21051  Autonomous Targeting of Infectious Superspread...
# 329  imxe4jeo  In Vitro Viability and Cytotoxicity Testing an...
#
#                               doi        date  \
# 515        10.1186/1472-6955-10-4  2011-02-16
# 725  10.1371/journal.pone.0029618  2012-01-03
# 76             10.1093/nar/gkl565  2006-09-29
# 522  10.1371/journal.pcbi.1002015  2011-03-17
# 329   10.2174/1875397300903010033  2009-06-11
#
#                                               abstract
# 515  BACKGROUND: The Vivian Bullwinkel Oration hono...
# 725  BACKGROUND: Multiple infections are common in ...
# 76   There is an increasing recognition that detail...
# 522  Infectious disease treatments, both pharmaceut...
# 329  In vitro cytotoxicity testing has become an in...

# %%
# Replace NaN values with an empty string in 'abstract'
docs['abstract'] = docs['abstract'].fillna('')

docs['title'] = docs['title'].fillna('')
# TF-IDF for key-phrase extraction
vectorizer = TfidfVectorizer(max_features=1000)
tfidf_matrix = vectorizer.fit_transform(docs['title'])

# Get feature names (key-phrases)
feature_names = vectorizer.get_feature_names_out()

# Example: Print top 10 key-phrases for the first document
print(feature_names)
# Out:
# ['15' '1918' '1999' '2001' '2006' '2007' '2008' '2009' '2010' '2011' '21'
#  'abstracts' 'ace2' 'acid' 'acquired' 'across' 'activated' 'activation'
#  'active' 'activity' 'acute' 'adaptive' 'adenovirus' 'adult' 'adults'
#  'advances' 'affecting' 'africa' 'age' 'agent' 'aids' 'air' 'airway'
#  'allograft' 'alternative' 'alveolar' 'america' 'amino' 'among'
#  'amplification' 'analysis' 'and' 'anemia' 'angiotensin' 'anti'
#  'antibodies' 'antibody' 'antigen' 'antigens' 'antisense' 'antiviral'
#  'application' 'applications' 'approach' 'approaches' 'ards' 'array'
#  'asia' 'assay' 'assessing' 'assessment' 'associated' 'association'
#  'attenuated' 'attitudes' 'australia' 'australian' 'autoimmune'
#  'autophagy' 'avian' 'bacterial' 'based' 'beijing' 'binding' 'biological'
#  'biology' 'bird' 'blood' 'bocavirus' 'bocaviruses' 'body' 'bone' 'borne'
#  'bovine' 'cancer' 'capacity' 'cardiac' 'cardiovascular' 'care' 'case'
#  'cases' 'cationic' 'caused' 'cd8' 'ceacam1' 'cell' 'cells' 'cellular'
#  'center' 'centre' 'century' 'challenges' 'changes' 'characteristics'
#  'characterization' 'chemical' 'chicken' 'chickens' 'chikungunya' 'child'
#  'children' 'china' 'chinese' 'chronic' 'class' 'clearance' 'clinical'
#  'clustering' 'codon' 'cohort' 'combination' 'combined' 'common'
#  'community' 'comparative' 'comparison' 'complement' 'complete' 'complex'
#  'complexity' 'composition' 'computational' 'conjugates' 'consensus'
#  'conserved' 'contact' 'contribute' 'contributes' 'control' 'controlled'
#  'converting' 'copy' 'core' 'cost' 'course' 'critical' 'critically'
#  'cross' 'culture' 'cynomolgus' 'cytokine' 'cytomegalovirus' 'cytoplasmic'
#  'data' 'database' 'dc' 'death' 'defense' 'degradation' 'deletion'
#  'delivery' 'dendritic' 'dengue' 'dependent' 'derived' 'description'
#  'design' 'detection' 'determinants' 'development' 'device' 'diabetes'
#  'diagnosis' 'diagnostic' 'diarrhea' 'different' 'differential' 'direct'
#  'discovery' 'disease' 'diseases' 'distance' 'distinct' 'distress'
#  'distribution' 'divergent' 'diversity' 'dna' 'domain' 'domains' 'drug'
#  'drugs' 'dual' 'due' 'duty' 'dynamic' 'dynamics' 'early' 'ebola' 'ecmo'
#  'effect' 'effective' 'effects' 'efficacy' 'efficient' 'electrospray'
#  'element' 'emergence' 'emergency' 'emerging' 'encephalitis' 'endogenous'
#  'endothelial' 'engineering' 'enhanced' 'enhances' 'enterovirus' 'entry'
#  'envelope' 'environmental' 'enzyme' 'epidemic' 'epidemics'
#  'epidemiological' 'epidemiology' 'epithelial' 'epitope' 'epitopes'
#  'errors' 'essential' 'estimate' 'eukaryotic' 'europe' 'european'
#  'evaluation' 'evidence' 'evolution' 'evolutionary' 'experience'
#  'exposure' 'expressed' 'expressing' 'expression' 'extracellular'
#  'extracorporeal' 'extracts' 'facilitates' 'factor' 'factors' 'failure'
#  'falciparum' 'family' 'fascicularis' 'features' 'feline' 'ferret'
#  'ferrets' 'fever' 'fibrosis' 'filovirus' 'findings' 'first' 'fitness'
#  'five' 'flavivirus' 'flaviviruses' 'flies' 'flight' 'flu' 'folding'
#  'follow' 'following' 'food' 'foot' 'formation' 'formula' 'found' 'four'
#  'frameshift' 'frameshifting' 'framework' 'free' 'frequency' 'function'
#  'functional' 'fusion' 'future' 'gabon' 'gamma' 'gammaherpesvirus' 'gaps'
#  'gender' 'gene' 'general' 'generation' 'genes' 'genetic' 'genetically'
#  'genetics' 'genome' 'genomes' 'genomic' 'genomics' 'genotype'
#  'genotyping' 'genus' 'geographic' 'germany' 'gii' 'global'
#  'globalization' 'glutathione' 'glycoprotein' 'glycosylation' 'gondii'
#  'graft' 'graph' 'great' 'greater' 'green' 'group' 'groups' 'growth'
#  'guide' 'h1n1' 'h5n1' 'h9n2' 'ha' 'hairpin' 'hantavirus' 'harboring'
#  'hcv' 'health' 'healthcare' 'heart' 'helical' 'hemagglutinin'
#  'hemophagocytic' 'hemorrhagic' 'hepatitis' 'hepatoma' 'herbal' 'herpes'
#  'herpesvirus' 'heterosubtypic' 'high' 'highly' 'histological'
#  'historical' 'hiv' 'hla' 'hmgb1' 'honey' 'hong' 'hopping' 'horizontal'
#  'hospital' 'hospitalized' 'host' 'household' 'households' 'human'
#  'humanized' 'humans' 'hybridization' 'hypothesis' 'icu' 'identification'
#  'identified' 'identifies' 'identify' 'identifying' 'idiopathic' 'ifn'
#  'igg' 'iggs' 'ii' 'il' 'ill' 'illness' 'imaging' 'immune' 'immunity'
#  'immunization' 'immunodeficiency' 'immunogenetic' 'immunoglobulins'
#  'immunological' 'immunoregulatory' 'impact' 'implications' 'important'
#  'improve' 'improved' 'improves' 'incidence' 'incorporation' 'increased'
#  'independent' 'indian' 'individuals' 'induce' 'induced' 'induces'
#  'inducing' 'induction' 'infected' 'infection' 'infections' 'infectious'
#  'inflammation' 'inflammatory' 'influence' 'influenza' 'information'
#  'inhibition' 'inhibitors' 'inhibits' 'initial' 'injury' 'innate'
#  'insertion' 'insight' 'insights' 'intensive' 'interaction' 'interactions'
#  'interferon' 'internal' 'international' 'interventions' 'intracellular'
#  'invasive' 'investigation' 'isolation' 'isothermal' 'italy' 'japanese'
#  'kawasaki' 'killer' 'kinase' 'knowledge' 'kong' 'laboratory' 'large'
#  'leads' 'length' 'lentiviral' 'lessons' 'lethal' 'levels' 'library'
#  'life' 'ligand' 'like' 'line' 'lines' 'lipid' 'listeria' 'literature'
#  'live' 'liver' 'long' 'loop' 'low' 'lung' 'lungs' 'macaques' 'macrophage'
#  'macrophages' 'mainland' 'making' 'malaria' 'mammalian' 'management'
#  'managing' 'mapping' 'markers' 'markets' 'marrow' 'mass' 'mathematical'
#  'may' 'measles' 'measures' 'mechanical' 'mechanism' 'mechanisms'
#  'mediated' 'medicine' 'medicines' 'membrane' 'membranes' 'meningitis'
#  'mesenchymal' 'meta' 'metabolic' 'metapneumovirus' 'method' 'methods'
#  'mice' 'microarray' 'microarrays' 'mitigation' 'mitochondrial' 'model'
#  'modeling' 'models' 'modification' 'modified' 'molecular' 'monitoring'
#  'monoclonal' 'monocytogenes' 'morphogenesis' 'morpholino' 'mortality'
#  'mosquito' 'mother' 'motif' 'motifs' 'mottle' 'mouse' 'mouth' 'mrna' 'ms'
#  'mucosal' 'multi' 'multicenter' 'multiple' 'multiplex' 'murine'
#  'mutation' 'mutational' 'mutations' 'mycobacterium' 'myeloid' 'myeloma'
#  'nanofluidic' 'nanoparticles' 'native' 'natural' 'naturally' 'necessary'
#  'neck' 'necrosis' 'netherlands' 'network' 'networks' 'neuraminidase'
#  'neutralizing' 'neutrophil' 'neutrophils' 'new' 'newly' 'next' 'nile'
#  'nipah' 'nitric' 'non' 'noninvasive' 'normal' 'norovirus' 'noroviruses'
#  'north' 'northern' 'novel' 'nss' 'nuclear' 'nucleic' 'nucleolus'
#  'nucleoprotein' 'nucleotide' 'number' 'numbers' 'nurses' 'observational'
#  'occult' 'occupational' 'occurring' 'old' 'oligomers' 'oligonucleotide'
#  'one' 'open' 'optic' 'optimism' 'optimized' 'oral' 'organ' 'organism'
#  'organisms' 'origin' 'oseltamivir' 'outbreak' 'outbreaks' 'outcome'
#  'outcomes' 'overall' 'ovine' 'oxidative' 'oxide' 'oxygenation'
#  'packaging' 'paediatric' 'pandemic' 'pandemics' 'paradigm'
#  'paramyxovirus' 'particles' 'pathogen' 'pathogenesis' 'pathogenic'
#  'pathogenicity' 'pathogens' 'pathological' 'pathway' 'pathways' 'patient'
#  'patients' 'pattern' 'patterns' 'pcr' 'pdm09' 'peptide' 'peptides'
#  'perception' 'perspective' 'perspectives' 'phage' 'pharmaceutical'
#  'phylogenetic' 'pilot' 'placental' 'planning' 'plant' 'plasmodium'
#  'platform' 'pneumococcal' 'pneumonia' 'pneumoniae' 'policy'
#  'polymorphism' 'polymorphisms' 'population' 'populations' 'porcine'
#  'pore' 'positive' 'possible' 'post' 'potential' 'poultry' 'practices'
#  'pre' 'precursor' 'predict' 'predicting' 'prediction' 'predictive'
#  'pregnancy' 'preparedness' 'presence' 'presenting' 'prevalence'
#  'prevention' 'primary' 'problems' 'processing' 'production' 'profile'
#  'profiles' 'profiling' 'prognosis' 'programmed' 'project' 'promoting'
#  'properties' 'prospective' 'prospects' 'protease' 'protective' 'protects'
#  'protein' 'proteins' 'proteome' 'proteomic' 'proteomics' 'pseudoknot'
#  'pseudoknots' 'psychological' 'public' 'pulmonary' 'qualitative'
#  'quality' 'quantitative' 'rabies' 'random' 'randomized' 'rapid' 'rate'
#  'reactive' 'real' 'recent' 'receptor' 'receptors' 'recombinant'
#  'recombination' 'recruitment' 'reduces' 'reducing' 'reduction'
#  'reference' 'region' 'regions' 'regulated' 'regulates' 'regulation'
#  'regulatory' 'related' 'relevance' 'renal' 'replication' 'report'
#  'reproduction' 'reproductive' 'required' 'requiring' 'research'
#  'resequencing' 'resistance' 'resistant' 'resource' 'respiratory'
#  'response' 'responses' 'results' 'retrospective' 'retroviral' 'reveals'
#  'reverse' 'review' 'rhinovirus' 'ribosomal' 'rift' 'risk' 'rna' 'rnas'
#  'role' 'roles' 'rotavirus' 'rt' 'sars' 'scale' 'sclerosis' 'score'
#  'screening' 'season' 'seasonal' 'secretion' 'sectional' 'selection'
#  'self' 'sensitive' 'sepsis' 'sequence' 'sequences' 'sequencing' 'series'
#  'serine' 'serum' 'severe' 'severity' 'sign' 'signal' 'signaling'
#  'signalling' 'signals' 'signature' 'significantly' 'signr' 'simple'
#  'single' 'site' 'sites' 'size' 'small' 'smallpox' 'society' 'south'
#  'spatial' 'species' 'specific' 'spread' 'st' 'stage' 'staphylococcus'
#  'state' 'states' 'status' 'stay' 'stem' 'stimulated' 'stimulation'
#  'stochastic' 'stomatitis' 'strain' 'strains' 'strand' 'strategies'
#  'strategy' 'streptococcus' 'stress' 'structural' 'structure' 'structures'
#  'students' 'studies' 'study' 'studying' 'substitution' 'subtype'
#  'subunit' 'successful' 'sufficient' 'suis' 'support' 'suppression'
#  'surfactant' 'surgical' 'surveillance' 'survey' 'survival' 'survivors'
#  'susceptibility' 'swine' 'symposium' 'symptom' 'symptomatic' 'syncytial'
#  'syndrome' 'syndromic' 'synergistic' 'synonymous' 'synthesis' 'synthetic'
#  'system' 'systematic' 'systemic' 'systems' 'tail' 'taiwan' 'target'
#  'targeted' 'targeting' 'targets' 'temperature' 'temperatures' 'temporal'
#  'term' 'terminal' 'termination' 'terminus' 'tertiary' 'testing'
#  'thailand' 'theory' 'therapeutic' 'therapeutics' 'therapies' 'therapy'
#  'thermal' 'thermodynamic' 'threats' 'three' 'throughput' 'tick' 'time'
#  'tissue' 'tlr2' 'to' 'tolerance' 'toll' 'tombusvirus' 'tool' 'tools'
#  'toward' 'towards' 'toxin' 'toxoplasma' 'traces' 'tracheal' 'tracing'
#  'tract' 'traditional' 'traits' 'transcriptional' 'transcriptomics'
#  'transfer' 'transgenic' 'translation' 'translational' 'transmembrane'
#  'transmissibility' 'transmission' 'transplant' 'transplantation'
#  'transport' 'travel' 'treat' 'treating' 'treatment' 'trends' 'triage'
#  'trial' 'trials' 'trimeric' 'trna' 'trojan' 'tropism' 'tuberculosis'
#  'tumor' 'two' 'type' 'unfolded' 'unifying' 'unique' 'unit' 'united'
#  'universal' 'university' 'unusual' 'up' 'update' 'upper' 'usage' 'use'
#  'used' 'user' 'using' 'vaccinated' 'vaccination' 'vaccine' 'vaccines'
#  'valley' 'value' 'var2csa' 'variability' 'variant' 'variants' 'variation'
#  'variations' 'vector' 'vectored' 'vectors' 'ventilation' 'ventilatory'
#  'versatile' 'versus' 'vesicular' 'via' 'vietnam' 'views' 'vignettes'
#  'viral' 'virion' 'virions' 'virology' 'virtual' 'virulence' 'virulent'
#  'virus' 'viruses' 'vitro' 'vivax' 'vivo' 'vsv' 'waves' 'weaning' 'web'
#  'west' 'western' 'whole' 'wide' 'wild' 'willingness' 'winter' 'within'
#  'without' 'women' 'workers' 'world' 'wu' 'year' 'years' 'yeast' 'zealand'
#  'zoonosis' 'zoonotic' 'κb']

# %%
# Use the TF-IDF vectorizer from the first block
vectorizer = TfidfVectorizer(max_features=1000)
tfidf_matrix = vectorizer.fit_transform(docs['title'])

# Get feature names (key-phrases)
feature_names = vectorizer.get_feature_names_out()

# Combine key phrases for each document
key_phrases_per_document = [set() for _ in range(len(docs))]
for i, row in enumerate(tfidf_matrix):
    # Get indices of non-zero elements (indicating presence of key phrases)
    indices = row.nonzero()[1]
    # Add corresponding key phrases to the set for the document
    key_phrases_per_document[i].update(feature_names[idx] for idx in indices)

# Create a dictionary to map query IDs to their respective key phrases
query_key_phrases = {query['query_id']: set(preprocess(query['title']).split()) for _, query in queries_data.iterrows()}

# Annotate queries based on the presence of key phrases
annotations = []
for query_id, key_phrases_query in query_key_phrases.items():
    # Check if any key phrase from the query is present in the document key phrases
    is_relevant = any(key_phrases_query.intersection(key_phrases_doc) for key_phrases_doc in key_phrases_per_document)
    annotations.append(1 if is_relevant else 0)

# Add the annotations to the DataFrame
queries_data["Annotations"] = annotations

# %%
from sklearn.metrics.pairwise import linear_kernel

# Compute TF-IDF matrix for queries
query_tfidf_matrix = vectorizer.transform(queries['title'])

# Compute cosine similarity between queries and documents
cosine_similarities = linear_kernel(query_tfidf_matrix, tfidf_matrix)

# Choose the number of top documents to keep
top_n = 1000  # Adjust this as needed

# Create a DataFrame to store the ranked list
ranked_list = pd.DataFrame(index=queries['query_id'], columns=range(top_n))

# Fill the DataFrame with top N document indices based on cosine similarity scores
for i, query_id in enumerate(queries['query_id']):
    # Get the indices of documents sorted by similarity score
    sorted_indices = np.argsort(cosine_similarities[i])[::-1][:top_n]
    # Assign the sorted indices to the corresponding row in the DataFrame
    ranked_list.loc[query_id] = sorted_indices

# Convert the values to numeric (since they might be stored as object)
ranked_list = ranked_list.apply(pd.to_numeric, errors='coerce')

# Display the ranked list
display(ranked_list.head())
# Out:
#              0      1      2      3      4       5      6      7      8    \
# query_id
# 1            765    310     14    571    489  192508  64175  64174  64173
# 2            598    855    335    791    347     443    719      4    199
# 3            834    608    306    512    343     206    672    484    827
# 4         192508  64165  64174  64173  64172   64171  64170  64169  64168
# 5            311    182    975    286    737     213  64168  64175  64174
#
#             9    ...    990    991    992    993    994    995    996    997  \
# query_id         ...
# 1         64172  ...  63216  63214  63261  63180  63189  63188  63187  63186
# 2           283  ...  63225  63245  63246  63247  63248  63267  63266  63265
# 3           192  ...  63248  63247  63246  63245  63244  63243  63218  63216
# 4         64167  ...  63186  63185  63184  63183  63182  63181  63180  63179
# 5         64173  ...  63241  63216  63214  63261  63180  63189  63188  63187
#
#             998    999
# query_id
# 1         63185  63184
# 2         63264  63263
# 3         63263  63182
# 4         63177  63211
# 5         63186  63185
#
# [5 rows x 1000 columns]

# %%
#queries_data = queries_data.drop(columns=['title'])

# Convert the indices in ranked_list to integers
ranked_list.index = ranked_list.index.astype(int)

# Filter out indices that are not present in queries_data
valid_indices = ranked_list.index.intersection(queries_data.index)

# Sort queries_data based on the filtered ranked list
sorted_queries_data = queries_data.loc[valid_indices]

# Save the sorted DataFrame to a CSV file
sorted_queries_data.to_csv("sorted_data.csv", sep=',', index=False, encoding='utf-8')

# Display the sorted DataFrame
display(sorted_queries_data)
# Out:
#    query_id                                  title  \
# 1         2   coronavirus response weather changes
# 2         3                   coronavirus immunity
# 3         4                 people die coronavirus
# 4         5                 animal models covid-19
# 5         6         coronavirus test rapid testing
# 6         7          serological tests coronavirus
# 7         8                  coronavirus reporting
# 8         9                     coronavirus canada
# 9        10   coronavirus social distancing impact
# 10       11         coronavirus hospital rationing
# 11       12                 coronavirus quarantine
# 12       13                     coronavirus spread
# 13       14            coronavirus super spreaders
# 14       15               coronavirus outside body
# 15       16      long coronavirus survive surfaces
# 16       17            coronavirus clinical trials
# 17       18              masks prevent coronavirus
# 18       19    alcohol sanitizer kills coronavirus
# 19       20             coronavirus ace inhibitors
# 20       21                  coronavirus mortality
# 21       22              coronavirus heart impacts
# 22       23               coronavirus hypertension
# 23       24                   coronavirus diabetes
# 24       25                 coronavirus biomarkers
# 25       26             coronavirus early symptoms
# 26       27               coronavirus asymptomatic
# 27       28         coronavirus hydroxychloroquine
# 28       29           coronavirus drug repurposing
# 29       30                 coronavirus remdesivir
# 30       31             difference coronavirus flu
# 31       32                   coronavirus subtypes
# 32       33         coronavirus vaccine candidates
# 33       34                   coronavirus recovery
# 34       35            coronavirus public datasets
# 35       36             sars-cov-2 spike structure
# 36       37       sars-cov-2 phylogenetic analysis
# 37       38            covid inflammatory response
# 38       39                covid-19 cytokine storm
# 39       40                  coronavirus mutations
# 40       41             covid-19 african-americans
# 41       42                       vitamin covid-19
# 42       43                      violence pandemic
# 43       44  impact masks coronavirus transmission
# 44       45       coronavirus mental health impact
# 45       46              dexamethasone coronavirus
# 46       47             covid-19 outcomes children
# 47       48           school reopening coronavirus
# 48       49       post-infection covid-19 immunity
# 49       50               mrna vaccine coronavirus
#
#                                           description  \
# 1                 coronavirus respond changes weather
# 2   sars-cov2 infected people develop immunity cro...
# 3                               causes death covid-19
# 4     drugs active sars-cov sars-cov-2 animal studies
# 5              types rapid testing covid-19 developed
# 6     serological tests detect antibodies coronavirus
# 7   lack testing availability led underreporting t...
# 8                            covid-19 affected canada
# 9    social distancing impact slowing spread covid-19
# 10  guidelines triaging patients infected coronavirus
# 11  best practices hospitals home maintaining quar...
# 12                    transmission routes coronavirus
# 13          evidence related covid-19 super spreaders
# 14                 long coronavirus live outside body
# 15            long coronavirus remain stable surfaces
# 16              clinical trials available coronavirus
# 17           best masks preventing infection covid-19
# 18        type hand sanitizer needed destroy covid-19
# 19  patients taking angiotensin-converting enzyme ...
# 20       mortality rates overall specific populations
# 21     cardiac complications likely patients covid-19
# 22  kinds complications related covid-19 associate...
# 23  kinds complications related covid-19 associate...
# 24  biomarkers predict severe clinical course 2019...
# 25                          initial symptoms covid-19
# 26               known infected covid-19 asymptomatic
# 27  evidence value hydroxychloroquine treating cov...
# 28  sars-cov-2 proteins-human proteins interaction...
# 29            remdesivir effective treatment covid-19
# 30                    coronavirus differ seasonal flu
# 31                                sars-cov-2 subtypes
# 32                 vaccine candidates tested covid-19
# 33         longer-term complications recover covid-19
# 34     new public datasets available related covid-19
# 35                 protein structure sars-cov-2 spike
# 36  result phylogenetic analysis sars-cov-2 genome...
# 37  mechanism inflammatory response pathogenesis c...
# 38         mechanism cytokine storm syndrome covid-19
# 39  observed mutations sars-cov-2 genome often mut...
# 40  impacts covid-19 among african-americans diffe...
# 41       vitamin impact covid-19 prevention treatment
# 42  covid-19 pandemic impacted violence society in...
# 43       much impact masks preventing spread covid-19
# 44           covid-19 pandemic impacted mental health
# 45          evidence dexamethasone treatment covid-19
# 46         health outcomes children contract covid-19
# 47  benefits risks re-opening schools midst covid-...
# 48  individuals recover covid-19 show sufficient i...
# 49                known mrna vaccine sars-cov-2 virus
#
#                                             narrative  Annotations
# 1   seeking range of information about the SARS-Co...            1
# 2   seeking studies of immunity developed due to i...            1
# 3   Studies looking at mechanisms of death from Co...            0
# 4   Papers that describe the results  of testing d...            1
# 5   Looking for studies identifying ways to diagno...            1
# 6   Looking for assays that measure immune respons...            0
# 7   Looking for studies answering questions of imp...            0
# 8   seeking data related to infections (confirm, s...            0
# 9   seeking specific information on studies that h...            1
# 10  Seeking information on any guidelines for prio...            1
# 11  Seeking information on best practices for acti...            0
# 12  Looking for information on all possible ways t...            1
# 13  seeking range of information related to the nu...            0
# 14  seeking range of information on the SARS-CoV-2...            1
# 15  Studies of time SARS-CoV-2 remains stable afte...            1
# 16  seeking specific COVID-19 clinical trials rang...            1
# 17  What types of masks should or should not be us...            0
# 18  Studies assessing chemicals and their concentr...            0
# 19  Looking for information on interactions betwee...            1
# 20  Seeking  information on COVID-19 fatality rate...            1
# 21  Seeking information on the types, frequency an...            1
# 22  seeking specific outcomes that hypertensive  (...            0
# 23  seeking specific outcomes that diabetic (any t...            1
# 24  Looking for information on biomarkers that pre...            0
# 25  Studies of patients and the first clinical man...            1
# 26  Studies of people who are known to be infected...            0
# 27  Basic science or clinical studies assessing th...            0
# 28  Seeking information about protein-protein inte...            1
# 29  seeking specific information on clinical outco...            0
# 30  Includes studies ranging from those focusing o...            1
# 31  Papers that discuss subtypes of the virus, fro...            0
# 32  Seeking studies that discuss possible, but spe...            1
# 33  Seeking information on the health outcomes for...            0
# 34  Seeking articles that specifically release new...            1
# 35  Looking for studies of the structure of the sp...            1
# 36  Looking for a range of studies which provide t...            1
# 37  Looking for a range of studies which describes...            1
# 38  Looking for studies that describes mechanism o...            1
# 39  Looking for studies that describes the emergen...            1
# 40  Looking for studies that analyze burden of ill...            0
# 41  This includes studies describing possible role...            0
# 42  Looking for analyses and data on how the pande...            1
# 43  Looking for studies of how masks slow SARS-CoV...            1
# 44  Includes increasing/decreasing rates of depres...            1
# 45  Looking for studies on the impact of dexametha...            0
# 46  Looking for studies on health outcomes in chil...            1
# 47  With the possibility of schools re-opening whi...            0
# 48  There is concern about re-infection for COVID-...            1
# 49  Looking for studies specifically focusing on m...            1

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

threshold = 20  # Example threshold, you can experiment with different values

# Create a list to store binary predicted labels for each query
predicted_labels = []

# Iterate over the ranked list for each query
for query_id in ranked_list.index:
    # Get the indices of the top documents based on the threshold
    top_documents_indices = ranked_list.loc[query_id][:threshold].tolist()

    # Create a binary label for each document based on whether it's in the top documents or not
    binary_labels = [1 if i in top_documents_indices else 0 for i in range(len(docs))]

    # Append the binary labels for the current query to the overall list
    predicted_labels.extend(binary_labels)

# Convert the list to a NumPy array for further calculations
predicted_labels = predicted_labels[:50]
predicted_labels = np.array(predicted_labels)

# Assuming 'annotations' is the ground truth and 'predicted_labels' is your predicted labels
precision = precision_score(annotations, predicted_labels, zero_division=0)
recall = recall_score(annotations, predicted_labels)
f1 = f1_score(annotations, predicted_labels)

print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
# Out:
# Precision: 1.0000
# Recall: 0.0323
# F1 Score: 0.0625
